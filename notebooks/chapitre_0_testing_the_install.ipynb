# %% [markdown]
# # Ce notebook est un test!
#
# ## Ceci est un sous-titre
#
# **Votre installation fonctionne si vous voyez ce texte ainsi que l'inteface de Jupyter Notebook / Jupyter Lab / Google Collab.**
#
# Vous êtes maintenant prêt à utiliser Google Colaboratory pour créer vos applications.

# %%
print("Hello World!")

a = 123
b = "Allo"

# %%
print(a)

# %%
print(a)
# Out:
# 123
